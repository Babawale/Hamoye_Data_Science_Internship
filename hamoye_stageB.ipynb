# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url= 'https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv'
data = pd.read_csv(url)
data.describe(include='all')
# Out:
#                        date    Appliances        lights            T1  \
# count                 19735  19735.000000  19735.000000  19735.000000
# unique                19735           NaN           NaN           NaN
# top     2016-03-18 06:30:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN     97.694958      3.801875     21.686571
# std                     NaN    102.524891      7.935988      1.606066
# min                     NaN     10.000000      0.000000     16.790000
# 25%                     NaN     50.000000      0.000000     20.760000
# 50%                     NaN     60.000000      0.000000     21.600000
# 75%                     NaN    100.000000      0.000000     22.600000
# max                     NaN   1080.000000     70.000000     26.260000
#
#                 RH_1            T2          RH_2            T3          RH_3  \
# ...

# %%
data.shape
# Out:
# (19735, 29)

# %%
data.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
data.isnull().any()
# Out:
# date           False
# Appliances     False
# lights         False
# T1             False
# RH_1           False
# T2             False
# RH_2           False
# T3             False
# RH_3           False
# T4             False
# RH_4           False
# T5             False
# RH_5           False
# T6             False
# RH_6           False
# T7             False
# RH_7           False
# T8             False
# RH_8           False
# T9             False
# RH_9           False
# T_out          False
# Press_mm_hg    False
# RH_out         False
# Windspeed      False
# Visibility     False
# Tdewpoint      False
# rv1            False
# rv2            False
# dtype: bool

# %%
data_corr = data.corr()
data_corr
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
fig, ax = plt.subplots(figsize = (20, 20))

sns.heatmap(data_corr, annot=True)

# %%
to_drop = ['date', 'lights']

# %%
# drop unnecessary columns
data.drop(to_drop, inplace=True, axis=1)
data.head(10)
# Out:
#    Appliances         T1       RH_1     T2       RH_2     T3       RH_3  \
# 0          60  19.890000  47.596667  19.20  44.790000  19.79  44.730000
# 1          60  19.890000  46.693333  19.20  44.722500  19.79  44.790000
# 2          50  19.890000  46.300000  19.20  44.626667  19.79  44.933333
# 3          50  19.890000  46.066667  19.20  44.590000  19.79  45.000000
# 4          60  19.890000  46.333333  19.20  44.530000  19.79  45.000000
# 5          50  19.890000  46.026667  19.20  44.500000  19.79  44.933333
# 6          60  19.890000  45.766667  19.20  44.500000  19.79  44.900000
# 7          60  19.856667  45.560000  19.20  44.500000  19.73  44.900000
# 8          60  19.790000  45.597500  19.20  44.433333  19.73  44.790000
# 9          70  19.856667  46.090000  19.23  44.400000  19.79  44.863333
#
#           T4       RH_4         T5  ...         T9   RH_9     T_out  \
# 0  19.000000  45.566667  17.166667  ...  17.033333  45.53  6.600000
# ...

# %%
#Normalise our dataset to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
features_data = normalised_data[['T2']]
target = normalised_data['T6']


#Split our dataset into the training and testing dataset.

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_data, target, test_size=0.3, random_state=42)

from sklearn.linear_model import LinearRegression
linear_model = LinearRegression(fit_intercept=True)

#fit the model to the training dataset
linear_model.fit(x_train,y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %% [markdown]
# ## Question 12

# %%
## R-squared.py
from sklearn.metrics import  r2_score
r2 = r2_score(y_test, predicted_values)
print('The R^2 value in two D.P is {}.'.format(round(r2, 2)))
# Out:
# The R^2 value in two D.P is 0.64.

# %% [markdown]
# ## Question 13

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
print('The Mean Absolute Error in two D.P is {}.'.format(round(mae, 2)))
# Out:
# The Mean Absolute Error in two D.P is 0.08.

# %% [markdown]
# ## Question 14

# %%
## Residual_Sum_of_Squares.py
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
print('The Residual Sum of Squares in two D.P is {}.'.format(round(rss, 3)))
# Out:
# The Residual Sum of Squares in two D.P is 66.116.

# %% [markdown]
# ## Question 15

# %%
## Root-Mean-Squared-Error.py
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
print('The Root Mean Squared Error in two D.P is {}.'.format(round(rmse, 2)))
# Out:
# The Root Mean Squared Error in two D.P is 0.11.

# %% [markdown]
# ## Question 16

# %%
print('The Coefficient of Determination is the same as the R^2 value in two D.P and is {}.'.format(round(r2, 2)))
# Out:
# The Coefficient of Determination is the same as the R^2 value in two D.P and is 0.64.

# %% [markdown]
# ## Question 17
# The model has only one feature i.e T2.

# %%
#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')

# %%
linear_model_weights
# Out:
#   Features  Linear_Model_Weight
# 0       T2             0.891077

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

# %% [markdown]
# ## Question 18
# The model has only one feature i.e T2

# %%
ridge_weights_df
# Out:
#   Features  Ridge_Weight
# 0       T2      0.890064

# %% [markdown]
# ## Question 19
# The model has only one feature i.e T2

# %%
lasso_weights_df
# Out:
#   Features  Lasso_weight
# 0       T2       0.85178

# %% [markdown]
# ## Question 20

# %%
predicted_values_lasso = lasso_reg.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, predicted_values_lasso))
print('The Root Mean Squared Error with the Lasso Regression in 3 D.P is {}.'.format(round(rmse, 3)))
# Out:
# The Root Mean Squared Error with the Lasso Regression in 3 D.P is 0.106.
